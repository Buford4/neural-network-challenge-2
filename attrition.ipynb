# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
try:
    # Attempt to import the dependencies
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import StandardScaler
    from sklearn.preprocessing import OneHotEncoder
    import pandas as pd
    import numpy as np
    from tensorflow.keras.models import Model
    from tensorflow.keras import layers

    # If the imports are successful, print a success message
    print("All dependencies are installed correctly.")
except ImportError as e:
    # If an ImportError occurs, print an error message with details
    print(f"An error occurred: {e}. Please ensure all dependencies are installed correctly.")
# Out:
# All dependencies are installed correctly.

# %%
# Determine the number of unique values in each column and sort them in descending order.
attrition_df.nunique().sort_values(ascending=False)
# Out:
# HourlyRate                  71
# Age                         43
# TotalWorkingYears           40
# YearsAtCompany              37
# DistanceFromHome            29
# YearsInCurrentRole          19
# YearsWithCurrManager        18
# YearsSinceLastPromotion     16
# PercentSalaryHike           15
# NumCompaniesWorked          10
# JobRole                      9
# TrainingTimesLastYear        7
# EducationField               6
# JobLevel                     5
# Education                    5
# EnvironmentSatisfaction      4
# JobInvolvement               4
# JobSatisfaction              4
# RelationshipSatisfaction     4
# StockOptionLevel             4
# WorkLifeBalance              4
# Department                   3
# BusinessTravel               3
# MaritalStatus                3
# OverTime                     2
# Attrition                    2
# PerformanceRating            2
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]
y_df.head()
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Create a list of at least 10 column names to use as X data
columns_list_for_X_data = ['HourlyRate',
                           'Age',
                           'TotalWorkingYears',
                           'YearsAtCompany',
                           'YearsInCurrentRole',
                           'YearsSinceLastPromotion',
                           'YearsWithCurrManager',
                           'DistanceFromHome',
                           'Education',
                           'JobLevel']
# # Create X_df using your selected columns
X_df = attrition_df[columns_list_for_X_data]

# Show the data types for X_df
print(X_df.dtypes)
# Out:
# HourlyRate                 int64
# Age                        int64
# TotalWorkingYears          int64
# YearsAtCompany             int64
# YearsInCurrentRole         int64
# YearsSinceLastPromotion    int64
# YearsWithCurrManager       int64
# DistanceFromHome           int64
# Education                  int64
# JobLevel                   int64
# dtype: object

# %%
# Check the new DataFrames
display('Input Features are labled as X_df:', X_df.head())
display('Target Variables are labled as y_df:', y_df.head())
# Out:
# 'Input Features are labled as X_df:'
#    HourlyRate  Age  TotalWorkingYears  YearsAtCompany  YearsInCurrentRole  \
# 0          94   41                  8               6                   4
# 1          61   49                 10              10                   7
# 2          92   37                  7               0                   0
# 3          56   33                  8               8                   7
# 4          40   27                  6               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  DistanceFromHome  Education  \
# 0                        0                     5                 1          2
# 1                        1                     7                 8          1
# 2                        0                     0                 2          2
# 3                        3                     0                 3          4
# 4                        2                     2                 2          1
#
#    JobLevel
# 0         2
# 1         2
# 2         1
# 3         1
# 4         1
# 'Target Variables are labled as y_df:'
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df)

display('X_train:', X_train.head())
display('X_test:', X_test.head())
display('y_train:', y_train.head())
display('y_test:', y_test.head())
# Out:
# 'X_train:'
#       HourlyRate  Age  TotalWorkingYears  YearsAtCompany  YearsInCurrentRole  \
# 1350          89   27                  9               8                   7
# 993           93   25                  6               3                   2
# 858           50   53                 26               7                   7
# 607           43   49                  9               9                   8
# 1139          35   32                  6               3                   2
#
#       YearsSinceLastPromotion  YearsWithCurrManager  DistanceFromHome  \
# 1350                        0                     7                 2
# 993                         1                     2                18
# 858                         4                     7                 7
# 607                         7                     7                11
# 1139                        0                     2                 5
#
#       Education  JobLevel
# 1350          2         2
# 993           1         2
# 858           2         5
# 607           3         3
# 1139          4         1
# 'X_test:'
#       HourlyRate  Age  TotalWorkingYears  YearsAtCompany  YearsInCurrentRole  \
# 487           83   20                  1               1                   0
# 1443          56   42                 24              22                   6
# 973           60   35                 10               9                   7
# 260          100   32                  5               5                   1
# 97            43   28                  5               5                   4
#
#       YearsSinceLastPromotion  YearsWithCurrManager  DistanceFromHome  \
# 487                         0                     0                 1
# 1443                        4                    14                 2
# 973                         0                     0                 1
# 260                         0                     3                 7
# 97                          0                     4                 4
#
#       Education  JobLevel
# 487           3         1
# 1443          3         5
# 973           3         2
# 260           3         1
# 97            3         2
# 'y_train:'
#      Attrition              Department
# 1350        No                   Sales
# 993         No                   Sales
# 858         No  Research & Development
# 607        Yes                   Sales
# 1139        No  Research & Development
# 'y_test:'
#      Attrition              Department
# 487         No  Research & Development
# 1443        No  Research & Development
# 973         No  Research & Development
# 260         No  Research & Development
# 97          No                   Sales

# %%
# Convert the X data to numeric data types for machine learning model with float32 for memory efficiency.
X_train_numeric_dtypes = X_train.astype('float32')
X_test_numeric_dtypes = X_test.astype('float32')

display('X_train_numeric_dtypes:', X_train_numeric_dtypes.head())
display('X_test_numeric_dtypes:', X_test_numeric_dtypes.head())
# Out:
# 'X_train_numeric_dtypes:'
#       HourlyRate   Age  TotalWorkingYears  YearsAtCompany  YearsInCurrentRole  \
# 1350        89.0  27.0                9.0             8.0                 7.0
# 993         93.0  25.0                6.0             3.0                 2.0
# 858         50.0  53.0               26.0             7.0                 7.0
# 607         43.0  49.0                9.0             9.0                 8.0
# 1139        35.0  32.0                6.0             3.0                 2.0
#
#       YearsSinceLastPromotion  YearsWithCurrManager  DistanceFromHome  \
# 1350                      0.0                   7.0               2.0
# 993                       1.0                   2.0              18.0
# 858                       4.0                   7.0               7.0
# 607                       7.0                   7.0              11.0
# 1139                      0.0                   2.0               5.0
#
#       Education  JobLevel
# 1350        2.0       2.0
# 993         1.0       2.0
# 858         2.0       5.0
# 607         3.0       3.0
# 1139        4.0       1.0
# 'X_test_numeric_dtypes:'
#       HourlyRate   Age  TotalWorkingYears  YearsAtCompany  YearsInCurrentRole  \
# 487         83.0  20.0                1.0             1.0                 0.0
# 1443        56.0  42.0               24.0            22.0                 6.0
# 973         60.0  35.0               10.0             9.0                 7.0
# 260        100.0  32.0                5.0             5.0                 1.0
# 97          43.0  28.0                5.0             5.0                 4.0
#
#       YearsSinceLastPromotion  YearsWithCurrManager  DistanceFromHome  \
# 487                       0.0                   0.0               1.0
# 1443                      4.0                  14.0               2.0
# 973                       0.0                   0.0               1.0
# 260                       0.0                   3.0               7.0
# 97                        0.0                   4.0               4.0
#
#       Education  JobLevel
# 487         3.0       1.0
# 1443        3.0       5.0
# 973         3.0       2.0
# 260         3.0       1.0
# 97          3.0       2.0

# %%
# Create a StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Fit the StandardScaler to the training data
X_scaler = scaler.fit(X_train)

# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
# Create a OneHotEncoder for the Department column
department_encoder = OneHotEncoder(handle_unknown='ignore')

department_encoder.fit(y_train[['Department']])

# Create two new variables by applying the encoder
# to the training and testing data
encoded_train = department_encoder.transform(y_train[['Department']])
encoded_test = department_encoder.transform(y_test[['Department']])

encoded_train_array = encoded_train.toarray()
encoded_train_array
# Out:
# array([[0., 0., 1.],
#        [0., 0., 1.],
#        [0., 1., 0.],
#        ...,
#        [0., 1., 0.],
#        [0., 0., 1.],
#        [0., 1., 0.]])

# %%
# Create a OneHotEncoder for the Attrition column
attrition_encoder = OneHotEncoder()

# Fit the encoder to the training data
attrition_encoder = attrition_encoder.fit(y_train[['Attrition']])

# Create two new variables by applying the encoder
# to the training and testing data
encoded_attrition_train = attrition_encoder.transform(y_train[['Attrition']])
encoded_attrition_test = attrition_encoder.transform(y_test[['Attrition']])

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data
input_features = len(X_train_scaled[0])

# Create the input layer
inputs = layers.Input(shape=(input_features,))
inputs

# Create at least two shared layers
shared_layer1 = layers.Dense(units=8, activation='relu')
shared_layer2 = layers.Dense(units=8, activation='relu')

# %%
# Create a branch for Department with a hidden layer and an output layer
department_branch = shared_layer1(inputs)
department_branch = shared_layer2(department_branch)

# Create the hidden layer
department_hidden = layers.Dense(units=8, activation='relu')(department_branch)

# Create the output layer
department_output = layers.Dense(units=3, activation='softmax', name='department_output')(department_hidden)

# %%
# Create a branch for Attrition with a hidden layer and an output layer
attrition_branch = shared_layer1(inputs)
attrition_branch = shared_layer2(attrition_branch)

# Create the hidden layer
attrition_hidden = layers.Dense(units=8, activation='relu')(attrition_branch)

# Create the output layer
attrition_output = layers.Dense(units=2, activation='softmax', name='attrition_output')(attrition_hidden)

# %%
# Create the model
model = Model(inputs=inputs, outputs=[department_output, attrition_output])

# Compile the model
model.compile(optimizer='adam',
              loss={'department_output': 'categorical_crossentropy',
                    'attrition_output': 'categorical_crossentropy'},
              metrics=['accuracy'])

# Summarize the model
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 10)]                 0         []
#
#  dense_4 (Dense)             (None, 8)                    88        ['input_2[0][0]',
#                                                                      'input_2[0][0]']
#
#  dense_5 (Dense)             (None, 8)                    72        ['dense_4[0][0]',
#                                                                      'dense_4[1][0]']
#
#  dense_6 (Dense)             (None, 8)                    72        ['dense_5[0][0]']
#
#  dense_7 (Dense)             (None, 8)                    72        ['dense_5[1][0]']
#
#  department_output (Dense)   (None, 3)                    27        ['dense_6[0][0]']
#
#  attrition_output (Dense)    (None, 2)                    18        ['dense_7[0][0]']
#
# ==================================================================================================
# Total params: 349 (1.36 KB)
# Trainable params: 349 (1.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import layers, Model

# Assuming 'input_features' is already defined
inputs = layers.Input(shape=(input_features,))

# Shared layers
shared_layer1 = layers.Dense(units=8, activation='relu')
shared_layer2 = layers.Dense(units=8, activation='relu')

# Department branch
department_branch = shared_layer1(inputs)
department_branch = shared_layer2(department_branch)
department_hidden = layers.Dense(units=8, activation='relu')(department_branch)
department_output = layers.Dense(units=3, activation='softmax', name='department_output')(department_hidden)

# Attrition branch
attrition_branch = shared_layer1(inputs)
attrition_branch = shared_layer2(attrition_branch)
attrition_hidden = layers.Dense(units=8, activation='relu')(attrition_branch)
attrition_output = layers.Dense(units=2, activation='softmax', name='attrition_output')(attrition_hidden)

# Recreate the model
model = Model(inputs=inputs, outputs=[department_output, attrition_output])

# Compile the model (you may need to adjust the loss and metrics)
model.compile(optimizer='adam',
              loss={'department_output': 'categorical_crossentropy',
                    'attrition_output': 'categorical_crossentropy'},
              metrics=['accuracy'])

# %%
# Check the shapes and types of your input and target data
print("X_train_scaled shape:", X_train_scaled.shape)
print("X_train_scaled type:", type(X_train_scaled))
print("encoded_train_array shape:", encoded_train_array.shape)
print("encoded_train_array type:", type(encoded_train_array))
print("encoded_attrition_train shape:", encoded_attrition_train.shape)
print("encoded_attrition_train type:", type(encoded_attrition_train))

# If the data is not in NumPy array format, convert it
import numpy as np

if not isinstance(X_train_scaled, np.ndarray):
    X_train_scaled = np.array(X_train_scaled)

if not isinstance(encoded_train_array, np.ndarray):
    encoded_train_array = encoded_train_array.toarray()  # Assuming it's a sparse matrix

if not isinstance(encoded_attrition_train, np.ndarray):
    encoded_attrition_train = encoded_attrition_train.toarray()  # Assuming it's a sparse matrix

# Verify that the data is not empty
print("X_train_scaled is empty:", X_train_scaled.size == 0)
print("encoded_train_array is empty:", encoded_train_array.size == 0)
print("encoded_attrition_train is empty:", encoded_attrition_train.size == 0)

# Train the model, assign the History object to a new variable
history = model.fit(X_train_scaled,
                    {'department_output': encoded_train_array, 'attrition_output': encoded_attrition_train},
                    epochs=100,
                    shuffle=True,
                    verbose=2)
# Out:
# X_train_scaled shape: (1102, 10)
# X_train_scaled type: <class 'numpy.ndarray'>
# encoded_train_array shape: (1102, 3)
# encoded_train_array type: <class 'numpy.ndarray'>
# encoded_attrition_train shape: (1102, 2)
# encoded_attrition_train type: <class 'numpy.ndarray'>
# X_train_scaled is empty: False
# encoded_train_array is empty: False
# encoded_attrition_train is empty: False
# Epoch 1/100
# 35/35 - 2s - loss: 1.6382 - department_output_loss: 1.1051 - attrition_output_loss: 0.5331 - department_output_accuracy: 0.3893 - attrition_output_accuracy: 0.8131 - 2s/epoch - 44ms/step
# Epoch 2/100
# 35/35 - 0s - loss: 1.5086 - department_output_loss: 1.0326 - attrition_output_loss: 0.4760 - department_output_accuracy: 0.6515 - attrition_output_accuracy: 0.8394 - 85ms/epoch - 2ms/step
# Epoch 3/100
# 35/35 - 0s - loss: 1.4286 - department_output_loss: 0.9793 - attrition_output_loss: 0.4493 - department_output_accuracy: 0.6615 - attrition_output_accuracy: 0.8394 - 72ms/epoch - 2ms/step
# Epoch 4/100
# 35/35 - 0s - loss: 1.3645 - department_output_loss: 0.9290 - attrition_output_loss: 0.4355 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8394 - 74ms/epoch - 2ms/step
# Epoch 5/100
# 35/35 - 0s - loss: 1.3095 - department_output_loss: 0.8834 - attrition_output_loss: 0.4261 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8394 - 68ms/epoch - 2ms/step
# Epoch 6/100
# 35/35 - 0s - loss: 1.2652 - department_output_loss: 0.8452 - attrition_output_loss: 0.4199 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8394 - 77ms/epoch - 2ms/step
# Epoch 7/100
# 35/35 - 0s - loss: 1.2341 - department_output_loss: 0.8188 - attrition_output_loss: 0.4152 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8394 - 79ms/epoch - 2ms/step
# Epoch 8/100
# 35/35 - 0s - loss: 1.2123 - department_output_loss: 0.8004 - attrition_output_loss: 0.4119 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8394 - 86ms/epoch - 2ms/step
# Epoch 9/100
# 35/35 - 0s - loss: 1.1990 - department_output_loss: 0.7896 - attrition_output_loss: 0.4094 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8394 - 79ms/epoch - 2ms/step
# Epoch 10/100
# 35/35 - 0s - loss: 1.1876 - department_output_loss: 0.7809 - attrition_output_loss: 0.4068 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8412 - 70ms/epoch - 2ms/step
# Epoch 11/100
# 35/35 - 0s - loss: 1.1800 - department_output_loss: 0.7753 - attrition_output_loss: 0.4048 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8421 - 72ms/epoch - 2ms/step
# Epoch 12/100
# 35/35 - 0s - loss: 1.1742 - department_output_loss: 0.7716 - attrition_output_loss: 0.4026 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8430 - 76ms/epoch - 2ms/step
# Epoch 13/100
# 35/35 - 0s - loss: 1.1711 - department_output_loss: 0.7686 - attrition_output_loss: 0.4024 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8403 - 74ms/epoch - 2ms/step
# Epoch 14/100
# 35/35 - 0s - loss: 1.1660 - department_output_loss: 0.7665 - attrition_output_loss: 0.3996 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8457 - 73ms/epoch - 2ms/step
# Epoch 15/100
# 35/35 - 0s - loss: 1.1635 - department_output_loss: 0.7647 - attrition_output_loss: 0.3988 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8448 - 87ms/epoch - 2ms/step
# Epoch 16/100
# 35/35 - 0s - loss: 1.1599 - department_output_loss: 0.7631 - attrition_output_loss: 0.3967 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8448 - 67ms/epoch - 2ms/step
# Epoch 17/100
# 35/35 - 0s - loss: 1.1584 - department_output_loss: 0.7615 - attrition_output_loss: 0.3969 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8457 - 69ms/epoch - 2ms/step
# Epoch 18/100
# 35/35 - 0s - loss: 1.1555 - department_output_loss: 0.7606 - attrition_output_loss: 0.3950 - department_output_accuracy: 0.6624 - attrition_output_accuracy: 0.8457 - 75ms/epoch - 2ms/step
# Epoch 19/100
# 35/35 - 0s - loss: 1.1518 - department_output_loss: 0.7589 - attrition_output_loss: 0.3929 - department_output_accuracy: 0.6652 - attrition_output_accuracy: 0.8521 - 77ms/epoch - 2ms/step
# Epoch 20/100
# 35/35 - 0s - loss: 1.1493 - department_output_loss: 0.7581 - attrition_output_loss: 0.3912 - department_output_accuracy: 0.6652 - attrition_output_accuracy: 0.8466 - 224ms/epoch - 6ms/step
# Epoch 21/100
# 35/35 - 0s - loss: 1.1492 - department_output_loss: 0.7571 - attrition_output_loss: 0.3921 - department_output_accuracy: 0.6661 - attrition_output_accuracy: 0.8521 - 150ms/epoch - 4ms/step
# Epoch 22/100
# 35/35 - 0s - loss: 1.1454 - department_output_loss: 0.7556 - attrition_output_loss: 0.3898 - department_output_accuracy: 0.6679 - attrition_output_accuracy: 0.8512 - 157ms/epoch - 4ms/step
# Epoch 23/100
# 35/35 - 0s - loss: 1.1440 - department_output_loss: 0.7550 - attrition_output_loss: 0.3890 - department_output_accuracy: 0.6642 - attrition_output_accuracy: 0.8557 - 182ms/epoch - 5ms/step
# Epoch 24/100
# 35/35 - 0s - loss: 1.1425 - department_output_loss: 0.7542 - attrition_output_loss: 0.3883 - department_output_accuracy: 0.6706 - attrition_output_accuracy: 0.8539 - 178ms/epoch - 5ms/step
# Epoch 25/100
# 35/35 - 0s - loss: 1.1406 - department_output_loss: 0.7534 - attrition_output_loss: 0.3872 - department_output_accuracy: 0.6715 - attrition_output_accuracy: 0.8557 - 153ms/epoch - 4ms/step
# Epoch 26/100
# 35/35 - 0s - loss: 1.1391 - department_output_loss: 0.7524 - attrition_output_loss: 0.3867 - department_output_accuracy: 0.6697 - attrition_output_accuracy: 0.8575 - 176ms/epoch - 5ms/step
# Epoch 27/100
# 35/35 - 0s - loss: 1.1376 - department_output_loss: 0.7516 - attrition_output_loss: 0.3860 - department_output_accuracy: 0.6697 - attrition_output_accuracy: 0.8575 - 171ms/epoch - 5ms/step
# Epoch 28/100
# 35/35 - 0s - loss: 1.1378 - department_output_loss: 0.7526 - attrition_output_loss: 0.3852 - department_output_accuracy: 0.6697 - attrition_output_accuracy: 0.8575 - 151ms/epoch - 4ms/step
# Epoch 29/100
# 35/35 - 0s - loss: 1.1347 - department_output_loss: 0.7501 - attrition_output_loss: 0.3846 - department_output_accuracy: 0.6697 - attrition_output_accuracy: 0.8593 - 243ms/epoch - 7ms/step
# Epoch 30/100
# 35/35 - 0s - loss: 1.1335 - department_output_loss: 0.7495 - attrition_output_loss: 0.3841 - department_output_accuracy: 0.6688 - attrition_output_accuracy: 0.8584 - 204ms/epoch - 6ms/step
# Epoch 31/100
# 35/35 - 0s - loss: 1.1333 - department_output_loss: 0.7491 - attrition_output_loss: 0.3842 - department_output_accuracy: 0.6688 - attrition_output_accuracy: 0.8557 - 175ms/epoch - 5ms/step
# Epoch 32/100
# 35/35 - 0s - loss: 1.1311 - department_output_loss: 0.7487 - attrition_output_loss: 0.3824 - department_output_accuracy: 0.6706 - attrition_output_accuracy: 0.8584 - 205ms/epoch - 6ms/step
# Epoch 33/100
# 35/35 - 0s - loss: 1.1296 - department_output_loss: 0.7476 - attrition_output_loss: 0.3820 - department_output_accuracy: 0.6697 - attrition_output_accuracy: 0.8584 - 262ms/epoch - 7ms/step
# Epoch 34/100
# 35/35 - 0s - loss: 1.1291 - department_output_loss: 0.7467 - attrition_output_loss: 0.3824 - department_output_accuracy: 0.6706 - attrition_output_accuracy: 0.8548 - 197ms/epoch - 6ms/step
# Epoch 35/100
# 35/35 - 0s - loss: 1.1279 - department_output_loss: 0.7463 - attrition_output_loss: 0.3816 - department_output_accuracy: 0.6688 - attrition_output_accuracy: 0.8584 - 207ms/epoch - 6ms/step
# Epoch 36/100
# 35/35 - 0s - loss: 1.1263 - department_output_loss: 0.7453 - attrition_output_loss: 0.3809 - department_output_accuracy: 0.6715 - attrition_output_accuracy: 0.8593 - 210ms/epoch - 6ms/step
# Epoch 37/100
# 35/35 - 0s - loss: 1.1255 - department_output_loss: 0.7451 - attrition_output_loss: 0.3804 - department_output_accuracy: 0.6751 - attrition_output_accuracy: 0.8584 - 162ms/epoch - 5ms/step
# Epoch 38/100
# 35/35 - 0s - loss: 1.1245 - department_output_loss: 0.7438 - attrition_output_loss: 0.3807 - department_output_accuracy: 0.6697 - attrition_output_accuracy: 0.8612 - 195ms/epoch - 6ms/step
# Epoch 39/100
# 35/35 - 0s - loss: 1.1233 - department_output_loss: 0.7431 - attrition_output_loss: 0.3802 - department_output_accuracy: 0.6715 - attrition_output_accuracy: 0.8603 - 263ms/epoch - 8ms/step
# Epoch 40/100
# 35/35 - 0s - loss: 1.1227 - department_output_loss: 0.7424 - attrition_output_loss: 0.3803 - department_output_accuracy: 0.6733 - attrition_output_accuracy: 0.8593 - 161ms/epoch - 5ms/step
# Epoch 41/100
# 35/35 - 0s - loss: 1.1228 - department_output_loss: 0.7430 - attrition_output_loss: 0.3798 - department_output_accuracy: 0.6742 - attrition_output_accuracy: 0.8575 - 231ms/epoch - 7ms/step
# Epoch 42/100
# 35/35 - 0s - loss: 1.1200 - department_output_loss: 0.7413 - attrition_output_loss: 0.3787 - department_output_accuracy: 0.6751 - attrition_output_accuracy: 0.8603 - 203ms/epoch - 6ms/step
# Epoch 43/100
# 35/35 - 0s - loss: 1.1192 - department_output_loss: 0.7411 - attrition_output_loss: 0.3781 - department_output_accuracy: 0.6742 - attrition_output_accuracy: 0.8584 - 208ms/epoch - 6ms/step
# Epoch 44/100
# 35/35 - 0s - loss: 1.1187 - department_output_loss: 0.7407 - attrition_output_loss: 0.3780 - department_output_accuracy: 0.6760 - attrition_output_accuracy: 0.8584 - 254ms/epoch - 7ms/step
# Epoch 45/100
# 35/35 - 0s - loss: 1.1177 - department_output_loss: 0.7403 - attrition_output_loss: 0.3774 - department_output_accuracy: 0.6742 - attrition_output_accuracy: 0.8593 - 210ms/epoch - 6ms/step
# Epoch 46/100
# 35/35 - 0s - loss: 1.1170 - department_output_loss: 0.7402 - attrition_output_loss: 0.3768 - department_output_accuracy: 0.6742 - attrition_output_accuracy: 0.8593 - 303ms/epoch - 9ms/step
# Epoch 47/100
# 35/35 - 0s - loss: 1.1161 - department_output_loss: 0.7390 - attrition_output_loss: 0.3771 - department_output_accuracy: 0.6760 - attrition_output_accuracy: 0.8584 - 200ms/epoch - 6ms/step
# Epoch 48/100
# 35/35 - 0s - loss: 1.1143 - department_output_loss: 0.7382 - attrition_output_loss: 0.3761 - department_output_accuracy: 0.6751 - attrition_output_accuracy: 0.8575 - 81ms/epoch - 2ms/step
# Epoch 49/100
# 35/35 - 0s - loss: 1.1139 - department_output_loss: 0.7382 - attrition_output_loss: 0.3757 - department_output_accuracy: 0.6806 - attrition_output_accuracy: 0.8584 - 80ms/epoch - 2ms/step
# Epoch 50/100
# 35/35 - 0s - loss: 1.1145 - department_output_loss: 0.7382 - attrition_output_loss: 0.3762 - department_output_accuracy: 0.6788 - attrition_output_accuracy: 0.8575 - 84ms/epoch - 2ms/step
# Epoch 51/100
# 35/35 - 0s - loss: 1.1125 - department_output_loss: 0.7374 - attrition_output_loss: 0.3751 - department_output_accuracy: 0.6842 - attrition_output_accuracy: 0.8575 - 75ms/epoch - 2ms/step
# Epoch 52/100
# 35/35 - 0s - loss: 1.1129 - department_output_loss: 0.7372 - attrition_output_loss: 0.3757 - department_output_accuracy: 0.6797 - attrition_output_accuracy: 0.8575 - 79ms/epoch - 2ms/step
# Epoch 53/100
# 35/35 - 0s - loss: 1.1119 - department_output_loss: 0.7368 - attrition_output_loss: 0.3751 - department_output_accuracy: 0.6833 - attrition_output_accuracy: 0.8593 - 82ms/epoch - 2ms/step
# Epoch 54/100
# 35/35 - 0s - loss: 1.1099 - department_output_loss: 0.7353 - attrition_output_loss: 0.3746 - department_output_accuracy: 0.6806 - attrition_output_accuracy: 0.8593 - 78ms/epoch - 2ms/step
# Epoch 55/100
# 35/35 - 0s - loss: 1.1088 - department_output_loss: 0.7350 - attrition_output_loss: 0.3738 - department_output_accuracy: 0.6869 - attrition_output_accuracy: 0.8575 - 78ms/epoch - 2ms/step
# Epoch 56/100
# 35/35 - 0s - loss: 1.1082 - department_output_loss: 0.7349 - attrition_output_loss: 0.3733 - department_output_accuracy: 0.6842 - attrition_output_accuracy: 0.8575 - 72ms/epoch - 2ms/step
# Epoch 57/100
# 35/35 - 0s - loss: 1.1067 - department_output_loss: 0.7336 - attrition_output_loss: 0.3732 - department_output_accuracy: 0.6860 - attrition_output_accuracy: 0.8603 - 73ms/epoch - 2ms/step
# Epoch 58/100
# 35/35 - 0s - loss: 1.1059 - department_output_loss: 0.7326 - attrition_output_loss: 0.3733 - department_output_accuracy: 0.6878 - attrition_output_accuracy: 0.8603 - 78ms/epoch - 2ms/step
# Epoch 59/100
# 35/35 - 0s - loss: 1.1054 - department_output_loss: 0.7320 - attrition_output_loss: 0.3734 - department_output_accuracy: 0.6833 - attrition_output_accuracy: 0.8612 - 90ms/epoch - 3ms/step
# Epoch 60/100
# 35/35 - 0s - loss: 1.1057 - department_output_loss: 0.7317 - attrition_output_loss: 0.3740 - department_output_accuracy: 0.6869 - attrition_output_accuracy: 0.8566 - 111ms/epoch - 3ms/step
# Epoch 61/100
# 35/35 - 0s - loss: 1.1051 - department_output_loss: 0.7319 - attrition_output_loss: 0.3732 - department_output_accuracy: 0.6842 - attrition_output_accuracy: 0.8566 - 77ms/epoch - 2ms/step
# Epoch 62/100
# 35/35 - 0s - loss: 1.1023 - department_output_loss: 0.7308 - attrition_output_loss: 0.3715 - department_output_accuracy: 0.6869 - attrition_output_accuracy: 0.8603 - 71ms/epoch - 2ms/step
# Epoch 63/100
# 35/35 - 0s - loss: 1.1016 - department_output_loss: 0.7303 - attrition_output_loss: 0.3712 - department_output_accuracy: 0.6869 - attrition_output_accuracy: 0.8584 - 77ms/epoch - 2ms/step
# Epoch 64/100
# 35/35 - 0s - loss: 1.1007 - department_output_loss: 0.7295 - attrition_output_loss: 0.3712 - department_output_accuracy: 0.6851 - attrition_output_accuracy: 0.8603 - 77ms/epoch - 2ms/step
# Epoch 65/100
# 35/35 - 0s - loss: 1.1012 - department_output_loss: 0.7295 - attrition_output_loss: 0.3717 - department_output_accuracy: 0.6860 - attrition_output_accuracy: 0.8584 - 72ms/epoch - 2ms/step
# Epoch 66/100
# 35/35 - 0s - loss: 1.1000 - department_output_loss: 0.7297 - attrition_output_loss: 0.3703 - department_output_accuracy: 0.6869 - attrition_output_accuracy: 0.8603 - 74ms/epoch - 2ms/step
# Epoch 67/100
# 35/35 - 0s - loss: 1.0986 - department_output_loss: 0.7283 - attrition_output_loss: 0.3703 - department_output_accuracy: 0.6860 - attrition_output_accuracy: 0.8584 - 70ms/epoch - 2ms/step
# Epoch 68/100
# 35/35 - 0s - loss: 1.0979 - department_output_loss: 0.7274 - attrition_output_loss: 0.3704 - department_output_accuracy: 0.6860 - attrition_output_accuracy: 0.8612 - 68ms/epoch - 2ms/step
# Epoch 69/100
# 35/35 - 0s - loss: 1.0961 - department_output_loss: 0.7270 - attrition_output_loss: 0.3692 - department_output_accuracy: 0.6887 - attrition_output_accuracy: 0.8612 - 75ms/epoch - 2ms/step
# Epoch 70/100
# 35/35 - 0s - loss: 1.0950 - department_output_loss: 0.7262 - attrition_output_loss: 0.3688 - department_output_accuracy: 0.6897 - attrition_output_accuracy: 0.8612 - 75ms/epoch - 2ms/step
# Epoch 71/100
# 35/35 - 0s - loss: 1.0940 - department_output_loss: 0.7255 - attrition_output_loss: 0.3685 - department_output_accuracy: 0.6869 - attrition_output_accuracy: 0.8557 - 83ms/epoch - 2ms/step
# Epoch 72/100
# 35/35 - 0s - loss: 1.0945 - department_output_loss: 0.7260 - attrition_output_loss: 0.3685 - department_output_accuracy: 0.6878 - attrition_output_accuracy: 0.8603 - 108ms/epoch - 3ms/step
# Epoch 73/100
# 35/35 - 0s - loss: 1.0928 - department_output_loss: 0.7249 - attrition_output_loss: 0.3679 - department_output_accuracy: 0.6878 - attrition_output_accuracy: 0.8593 - 78ms/epoch - 2ms/step
# Epoch 74/100
# 35/35 - 0s - loss: 1.0916 - department_output_loss: 0.7243 - attrition_output_loss: 0.3674 - department_output_accuracy: 0.6915 - attrition_output_accuracy: 0.8584 - 82ms/epoch - 2ms/step
# Epoch 75/100
# 35/35 - 0s - loss: 1.0902 - department_output_loss: 0.7232 - attrition_output_loss: 0.3670 - department_output_accuracy: 0.6887 - attrition_output_accuracy: 0.8593 - 73ms/epoch - 2ms/step
# Epoch 76/100
# 35/35 - 0s - loss: 1.0913 - department_output_loss: 0.7232 - attrition_output_loss: 0.3681 - department_output_accuracy: 0.6869 - attrition_output_accuracy: 0.8603 - 77ms/epoch - 2ms/step
# Epoch 77/100
# 35/35 - 0s - loss: 1.0894 - department_output_loss: 0.7229 - attrition_output_loss: 0.3666 - department_output_accuracy: 0.6924 - attrition_output_accuracy: 0.8593 - 73ms/epoch - 2ms/step
# Epoch 78/100
# 35/35 - 0s - loss: 1.0894 - department_output_loss: 0.7224 - attrition_output_loss: 0.3670 - department_output_accuracy: 0.6924 - attrition_output_accuracy: 0.8612 - 73ms/epoch - 2ms/step
# Epoch 79/100
# 35/35 - 0s - loss: 1.0897 - department_output_loss: 0.7226 - attrition_output_loss: 0.3672 - department_output_accuracy: 0.6887 - attrition_output_accuracy: 0.8603 - 81ms/epoch - 2ms/step
# Epoch 80/100
# 35/35 - 0s - loss: 1.0868 - department_output_loss: 0.7206 - attrition_output_loss: 0.3662 - department_output_accuracy: 0.6942 - attrition_output_accuracy: 0.8593 - 73ms/epoch - 2ms/step
# Epoch 81/100
# 35/35 - 0s - loss: 1.0867 - department_output_loss: 0.7206 - attrition_output_loss: 0.3662 - department_output_accuracy: 0.6915 - attrition_output_accuracy: 0.8603 - 72ms/epoch - 2ms/step
# Epoch 82/100
# 35/35 - 0s - loss: 1.0855 - department_output_loss: 0.7195 - attrition_output_loss: 0.3660 - department_output_accuracy: 0.6915 - attrition_output_accuracy: 0.8612 - 75ms/epoch - 2ms/step
# Epoch 83/100
# 35/35 - 0s - loss: 1.0856 - department_output_loss: 0.7194 - attrition_output_loss: 0.3663 - department_output_accuracy: 0.6906 - attrition_output_accuracy: 0.8584 - 108ms/epoch - 3ms/step
# Epoch 84/100
# 35/35 - 0s - loss: 1.0844 - department_output_loss: 0.7196 - attrition_output_loss: 0.3648 - department_output_accuracy: 0.6924 - attrition_output_accuracy: 0.8603 - 87ms/epoch - 2ms/step
# Epoch 85/100
# 35/35 - 0s - loss: 1.0829 - department_output_loss: 0.7189 - attrition_output_loss: 0.3640 - department_output_accuracy: 0.6933 - attrition_output_accuracy: 0.8621 - 80ms/epoch - 2ms/step
# Epoch 86/100
# 35/35 - 0s - loss: 1.0828 - department_output_loss: 0.7181 - attrition_output_loss: 0.3647 - department_output_accuracy: 0.6933 - attrition_output_accuracy: 0.8621 - 84ms/epoch - 2ms/step
# Epoch 87/100
# 35/35 - 0s - loss: 1.0811 - department_output_loss: 0.7174 - attrition_output_loss: 0.3638 - department_output_accuracy: 0.6942 - attrition_output_accuracy: 0.8621 - 73ms/epoch - 2ms/step
# Epoch 88/100
# 35/35 - 0s - loss: 1.0808 - department_output_loss: 0.7167 - attrition_output_loss: 0.3641 - department_output_accuracy: 0.6978 - attrition_output_accuracy: 0.8603 - 71ms/epoch - 2ms/step
# Epoch 89/100
# 35/35 - 0s - loss: 1.0801 - department_output_loss: 0.7164 - attrition_output_loss: 0.3637 - department_output_accuracy: 0.6960 - attrition_output_accuracy: 0.8612 - 70ms/epoch - 2ms/step
# Epoch 90/100
# 35/35 - 0s - loss: 1.0801 - department_output_loss: 0.7166 - attrition_output_loss: 0.3636 - department_output_accuracy: 0.6906 - attrition_output_accuracy: 0.8603 - 76ms/epoch - 2ms/step
# Epoch 91/100
# 35/35 - 0s - loss: 1.0787 - department_output_loss: 0.7152 - attrition_output_loss: 0.3634 - department_output_accuracy: 0.6933 - attrition_output_accuracy: 0.8603 - 78ms/epoch - 2ms/step
# Epoch 92/100
# 35/35 - 0s - loss: 1.0775 - department_output_loss: 0.7148 - attrition_output_loss: 0.3627 - department_output_accuracy: 0.6960 - attrition_output_accuracy: 0.8603 - 73ms/epoch - 2ms/step
# Epoch 93/100
# 35/35 - 0s - loss: 1.0774 - department_output_loss: 0.7137 - attrition_output_loss: 0.3637 - department_output_accuracy: 0.6933 - attrition_output_accuracy: 0.8612 - 68ms/epoch - 2ms/step
# Epoch 94/100
# 35/35 - 0s - loss: 1.0765 - department_output_loss: 0.7135 - attrition_output_loss: 0.3630 - department_output_accuracy: 0.6942 - attrition_output_accuracy: 0.8603 - 69ms/epoch - 2ms/step
# Epoch 95/100
# 35/35 - 0s - loss: 1.0766 - department_output_loss: 0.7138 - attrition_output_loss: 0.3628 - department_output_accuracy: 0.6933 - attrition_output_accuracy: 0.8612 - 106ms/epoch - 3ms/step
# Epoch 96/100
# 35/35 - 0s - loss: 1.0756 - department_output_loss: 0.7125 - attrition_output_loss: 0.3631 - department_output_accuracy: 0.6969 - attrition_output_accuracy: 0.8584 - 82ms/epoch - 2ms/step
# Epoch 97/100
# 35/35 - 0s - loss: 1.0762 - department_output_loss: 0.7136 - attrition_output_loss: 0.3626 - department_output_accuracy: 0.6942 - attrition_output_accuracy: 0.8584 - 72ms/epoch - 2ms/step
# Epoch 98/100
# 35/35 - 0s - loss: 1.0738 - department_output_loss: 0.7124 - attrition_output_loss: 0.3614 - department_output_accuracy: 0.6942 - attrition_output_accuracy: 0.8584 - 67ms/epoch - 2ms/step
# Epoch 99/100
# 35/35 - 0s - loss: 1.0736 - department_output_loss: 0.7117 - attrition_output_loss: 0.3619 - department_output_accuracy: 0.6960 - attrition_output_accuracy: 0.8612 - 69ms/epoch - 2ms/step
# Epoch 100/100
# 35/35 - 0s - loss: 1.0719 - department_output_loss: 0.7112 - attrition_output_loss: 0.3608 - department_output_accuracy: 0.6951 - attrition_output_accuracy: 0.8612 - 72ms/epoch - 2ms/step

# %%
# Evaluate the model with the testing data
results = model.evaluate(X_test_scaled,
                         {'department_output': encoded_test.toarray(),
                          'attrition_output': encoded_attrition_test.toarray()}, # Convert sparse matrices to dense arrays
                         verbose=2)

# Access the metrics as needed
model_loss = results[0]  # Overall loss
department_loss = results[1]  # Loss for department output
department_accuracy = results[2]  # Accuracy for department output
attrition_loss = results[3]  # Loss for attrition output
attrition_accuracy = results[4]  # Accuracy for attrition output

print("Overall Loss:", model_loss)
print("Department Loss:", department_loss)
print("Department Accuracy:", department_accuracy)
print("Attrition Loss:", attrition_loss)
print("Attrition Accuracy:", attrition_accuracy)
# Out:
# 12/12 - 0s - loss: 1.2167 - department_output_loss: 0.7490 - attrition_output_loss: 0.4677 - department_output_accuracy: 0.6332 - attrition_output_accuracy: 0.8261 - 136ms/epoch - 11ms/step
# Overall Loss: 1.2167096138000488
# Department Loss: 0.749003529548645
# Department Accuracy: 0.4677060544490814
# Attrition Loss: 0.633152186870575
# Attrition Accuracy: 0.8260869383811951

# %%
# Evaluate the model with the testing data
results = model.evaluate(X_test_scaled,
                         {'department_output': encoded_test.toarray(),
                          'attrition_output': encoded_attrition_test.toarray()}, # Convert sparse matrices to dense arrays
                         verbose=2)

# Access the metrics as needed
model_loss = results[0]  # Overall loss
department_loss = results[1]  # Loss for department output
department_accuracy = results[2]  # Accuracy for department output
attrition_loss = results[3]  # Loss for attrition output
attrition_accuracy = results[4]  # Accuracy for attrition output

# Print the accuracy for both department and attrition
print(f"Department Accuracy: {department_accuracy}, Attrition Accuracy: {attrition_accuracy}")
# Out:
# 12/12 - 0s - loss: 1.2167 - department_output_loss: 0.7490 - attrition_output_loss: 0.4677 - department_output_accuracy: 0.6332 - attrition_output_accuracy: 0.8261 - 81ms/epoch - 7ms/step
# Department Accuracy: 0.4677060544490814, Attrition Accuracy: 0.8260869383811951

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. It would seem that accuracy is not the best metric to use on this data. This is because the data is imbalanced, with the majority of the data being of the negative class. This means that a model that predicts all data points as the negative class would have a high accuracy, but would not be useful. Instead, we could use precision and recall to evaluate the model.
# 2. The activation function I chose for the output layer is the sigmoid function. This is because the output layer is a binary classification problem, and the sigmoid function is well-suited for binary classification problems.
# 3. A few ways that this model might be improved include:
#     - Using a more complex model, such as a deep neural network with more layers and neurons.
#     - Tuning the hyperparameters of the model, such as the learning rate, batch size, and number of epochs.
#     - Using techniques such as data augmentation to increase the size of the training data.
#     - Using techniques such as dropout to prevent overfitting.
#     - Using techniques such as batch normalization to improve the training of the model.
